# %%
student_grades = {"Mary": 85, "John": 90, "Alice": 78, "Bob": 92}

# %% [markdown]
# ## Dictionarys Syntax
# name = {"key":Value,"key":Value}

# %%
day_temperatures = {"morning": 25.2, "noon": 35.1, "evening": 29.8}
